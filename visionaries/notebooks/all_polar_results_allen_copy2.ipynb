# %% [markdown]
# # Draw polar plots for all categories

# %%
# See this for the list of valid ones https://pastebin.com/NGzvE0Ky
interesting_categories = [
#  ('VISp', [175, 185, 205], ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Slc17a7-IRES2-Cre']),
   ('VISp', [275, 335, 350], ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Rorb-IRES2-Cre', 'Scnn1a-Tg3-Cre']),
   ('VISp', [375, 390, 400], ['Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Fezf2-CreER', 'Rbp4-Cre_KL100', 'Tlx3-Cre_PL56']),
   ('VISp', [550], ['Ntsr1-Cre_GN220']),
   ('VISp', [175, 185, 195, 200, 225, 275], ['Pvalb-IRES-Cre']),
   ('VISp', [175, 275], ['Vip-IRES-Cre']),
   ('VISp', [265, 285, 350], ['Sst-IRES-Cre']),
   ('VISal', [175, 265], ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre']),
   ('VISal', [275], ['Sst-IRES-Cre']),
   ('VISal', [275, 276, 300, 350], ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre']),
   ('VISal', [365, 375], ['Emx1-IRES-Cre', 'Rbp4-Cre_KL100']),
   ('VISam', [175], ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre']),
   ('VISam', [275, 320, 325, 350], ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre']),
   ('VISam', [375], ['Emx1-IRES-Cre', 'Rbp4-Cre_KL100']),
   ('VISl', [175], ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre']),
   ('VISl', [275, 325, 350], ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre']),
   ('VISl', [375, 400], ['Fezf2-CreER', 'Rbp4-Cre_KL100', 'Tlx3-Cre_PL56 ', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre']),
   ('VISl', [550, 570, 625], ['Ntsr1-Cre_GN220']),
   ('VISl', [175, 250, 275], ['Vip-IRES-Cre']),
   ('VISl', [250, 275], ['Sst-IRES-Cre']),
   ('VISl', [375], ['Sst-IRES-Cre']),
   ('VISpm', [175], ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre']),
   ('VISpm', [275, 300, 325, 335, 350], ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre']),
   ('VISpm', [550], ['Ntsr1-Cre_GN220']),
   ('VISpm', [175, 275], ['Vip-IRES-Cre']),
   ('VISpm', [275, 300, 325, 350, 375], ['Sst-IRES-Cre']),
   ('VISrl', [175], ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre']),
   ('VISrl', [275, 350], ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre']),
   ('VISrl', [375], ['Rbp4-Cre_KL100 ', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre']),
   ('VISrl', [375], ['Sst-IRES-Cre'])
]
    
dsi_dg_threshold = 0.5

# %%
import os
drive_path = '/media/stephen/Brain20191/allen-brain-observatory/visual-coding-2p/'
if not os.path.isdir(drive_path):
    drive_path = '/media/alihamodi/Brain2019/allen-brain-observatory/visual-coding-2p/'
    
import warnings; warnings.simplefilter('ignore');
from utils.polarplot import *
from utils.polardata import *
from utils.data_wrappers import *
import os
import pandas as pd
from allensdk.core.brain_observatory_cache import BrainObservatoryCache
import allensdk.brain_observatory.stimulus_info as stim_info
from utils.data_wrappers import *
manifest_file = os.path.join(drive_path,'manifest.json')
boc = BrainObservatoryCache(manifest_file=manifest_file)

cells = boc.get_cell_specimens()
cells = pd.DataFrame.from_records(cells)

# %%
get_one_category_polar_data_cache = {}

# %%
def get_avg_cell_polar_in_experiment(boc, ec_id, exp_id, cells):
    """
    Get the polar data for all cells in this experiment, then average them out to get a single polar data.
    """
    in_category_cells = cells[cells.experiment_container_id == ec_id]
    dg_response_filter = get_dg_response_filter_from_saskia()
    filtered_cells = get_filtered_cells(in_category_cells, dg_response_filter)
    filtered_cells = filtered_cells[filtered_cells.dsi_dg > dsi_dg_threshold]
    print ("In this experiment, we have", len(in_category_cells),
           "cells, but after filtering, we have", len(filtered_cells), "cells")
    
    thetas = []
    rs = []
    cell_ids = []
    data_set = boc.get_ophys_experiment_data(exp_id)
    for ii, row in filtered_cells.iterrows():
        cell_specimen_id = row.cell_specimen_id
        pref_tf = row.pref_tf
        one_cell_polar_data_dict = get_avg_normalized_response(
            data_set=data_set,
            cell_specimen_id = cell_specimen_id,
            temporal_frequency=pref_tf)
        if one_cell_polar_data_dict is None:
            continue
        theta, r = convert_polar_dict_to_arrays(one_cell_polar_data_dict)
        thetas.append(theta)
        rs.append(r)
        cell_ids.append(cell_specimen_id)
        
    print ("In this experiment, we have", len(in_category_cells),
           "cells, but after filtering and removing negative mean dffs, we have", len(thetas), "cells")
    if len(thetas) == 0:
        return None, None, None
    agg_theta, agg_r = get_avg_polar(thetas, rs)
    return agg_theta, agg_r, len(thetas)

# %%
def get_one_category_polar_data(boc, targeted_structure, imaging_depths, cre_lines):
    cache_key = (targeted_structure, tuple(imaging_depths), tuple(cre_lines))
    if cache_key in get_one_category_polar_data_cache:
        return get_one_category_polar_data_cache[cache_key]
    
    exps = boc.get_ophys_experiments(stimuli=[stim_info.DRIFTING_GRATINGS],
        targeted_structures = [targeted_structure],
        imaging_depths = imaging_depths,
        cre_lines = cre_lines)
    if len(exps) == 0:
        return None, None, None, None
    print ("There are", len(exps), "experiments for ", targeted_structure, imaging_depths, cre_lines)
    
    thetas = []
    rs = []
    total_num_cells = 0
    for exp in exps:
        e_id = exp['id']
        ec_id = exp['experiment_container_id']
        print("Processing experiment", e_id)
        theta, r, num_cells = get_avg_cell_polar_in_experiment(boc, ec_id, e_id, cells)
        if theta is None or len(theta) == 0:
            continue
        thetas.append(theta)
        rs.append(r)
        total_num_cells += num_cells
        
    agg_theta, agg_r = get_avg_polar(thetas, rs)
    
    if len(thetas) == 0:
        agg_theta, agg_r, thetas, rs, total_num_cells= None, None, None, None, None
    
    get_one_category_polar_data_cache[cache_key] = (agg_theta, agg_r, thetas, rs, total_num_cells)
    return get_one_category_polar_data_cache[cache_key]

# %%
import warnings; warnings.simplefilter('ignore');
for targeted_structure, imaging_depths, cre_lines in interesting_categories:
    agg_theta, agg_r, thetas, rs, num_cells = get_one_category_polar_data(
        boc,
        targeted_structure,
        imaging_depths,
        cre_lines)
    if agg_theta is None:
        continue
    
    print(targeted_structure, imaging_depths, cre_lines, "#Experiments: ", len(thetas), "#Cells:", num_cells, "circ var:", circ_var(np.array(agg_theta), np.array(agg_r)))
    plot_test(np.array(agg_theta), np.array(agg_r))
    
    
    max_r = max(np.array(agg_r).max(), np.array(rs).max())

    agg_r_np = np.array(agg_r)
    agg_r_np = agg_r_np / max_r
    rs_np = np.array(rs)
    rs_np = rs_np / max_r
    fig, ax = plt.subplots(nrows=1, ncols=1, subplot_kw=dict(polar=True))
    polar_plot_population(ax=ax,
        bold_theta = agg_theta,
        bold_r = agg_r_np,
        grey_thetas = thetas, 
        grey_rs = rs_np)
    plt.show()
    filename = "{}_cell{}_exp{}_depths{}_crelines{}".format(
        targeted_structure,
        num_cells,
        len(thetas),
        imaging_depths,
        cre_lines)
    fig.savefig('../results/autopics/{}.png'.format(filename))
# Out:
# There are 34 experiments for  VISp [275, 335, 350] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Rorb-IRES2-Cre', 'Scnn1a-Tg3-Cre']
# Processing experiment 510214538
# In this experiment, we have 390 cells, but after filtering, we have 119 cells
# In this experiment, we have 390 cells, but after filtering and removing negative mean dffs, we have 119 cells
# Processing experiment 528402271
# In this experiment, we have 265 cells, but after filtering, we have 85 cells
# In this experiment, we have 265 cells, but after filtering and removing negative mean dffs, we have 85 cells
# Processing experiment 644026238
# In this experiment, we have 376 cells, but after filtering, we have 66 cells
# In this experiment, we have 376 cells, but after filtering and removing negative mean dffs, we have 66 cells
# Processing experiment 503109347
# In this experiment, we have 520 cells, but after filtering, we have 133 cells
# In this experiment, we have 520 cells, but after filtering and removing negative mean dffs, we have 133 cells
# Processing experiment 524691284
# In this experiment, we have 389 cells, but after filtering, we have 126 cells
# In this experiment, we have 389 cells, but after filtering and removing negative mean dffs, we have 126 cells
# Processing experiment 587344053
# In this experiment, we have 304 cells, but after filtering, we have 106 cells
# In this experiment, we have 304 cells, but after filtering and removing negative mean dffs, we have 106 cells
# Processing experiment 596584192
# In this experiment, we have 388 cells, but after filtering, we have 136 cells
# In this experiment, we have 388 cells, but after filtering and removing negative mean dffs, we have 136 cells
# Processing experiment 501574836
# In this experiment, we have 313 cells, but after filtering, we have 83 cells
# In this experiment, we have 313 cells, but after filtering and removing negative mean dffs, we have 83 cells
# Processing experiment 590168385
# In this experiment, we have 199 cells, but after filtering, we have 78 cells
# In this experiment, we have 199 cells, but after filtering and removing negative mean dffs, we have 78 cells
# Processing experiment 657080632
# In this experiment, we have 320 cells, but after filtering, we have 77 cells
# In this experiment, we have 320 cells, but after filtering and removing negative mean dffs, we have 77 cells
# Processing experiment 645413759
# In this experiment, we have 300 cells, but after filtering, we have 124 cells
# In this experiment, we have 300 cells, but after filtering and removing negative mean dffs, we have 124 cells
# Processing experiment 541290571
# In this experiment, we have 302 cells, but after filtering, we have 44 cells
# In this experiment, we have 302 cells, but after filtering and removing negative mean dffs, we have 44 cells
# Processing experiment 508753256
# In this experiment, we have 158 cells, but after filtering, we have 46 cells
# In this experiment, we have 158 cells, but after filtering and removing negative mean dffs, we have 46 cells
# Processing experiment 679702884
# In this experiment, we have 554 cells, but after filtering, we have 124 cells
# In this experiment, we have 554 cells, but after filtering and removing negative mean dffs, we have 124 cells
# Processing experiment 531348161
# In this experiment, we have 250 cells, but after filtering, we have 90 cells
# In this experiment, we have 250 cells, but after filtering and removing negative mean dffs, we have 90 cells
# Processing experiment 530645663
# In this experiment, we have 167 cells, but after filtering, we have 12 cells
# In this experiment, we have 167 cells, but after filtering and removing negative mean dffs, we have 12 cells
# Processing experiment 561312435
# In this experiment, we have 390 cells, but after filtering, we have 108 cells
# In this experiment, we have 390 cells, but after filtering and removing negative mean dffs, we have 108 cells
# Processing experiment 661328410
# In this experiment, we have 284 cells, but after filtering, we have 51 cells
# In this experiment, we have 284 cells, but after filtering and removing negative mean dffs, we have 51 cells
# Processing experiment 702934964
# In this experiment, we have 188 cells, but after filtering, we have 39 cells
# In this experiment, we have 188 cells, but after filtering and removing negative mean dffs, we have 39 cells
# Processing experiment 511534603
# In this experiment, we have 295 cells, but after filtering, we have 39 cells
# In this experiment, we have 295 cells, but after filtering and removing negative mean dffs, we have 39 cells
# Processing experiment 539497234
# In this experiment, we have 111 cells, but after filtering, we have 24 cells
# In this experiment, we have 111 cells, but after filtering and removing negative mean dffs, we have 24 cells
# Processing experiment 653122667
# In this experiment, we have 400 cells, but after filtering, we have 105 cells
# In this experiment, we have 400 cells, but after filtering and removing negative mean dffs, we have 105 cells
# Processing experiment 501729039
# In this experiment, we have 307 cells, but after filtering, we have 97 cells
# In this experiment, we have 307 cells, but after filtering and removing negative mean dffs, we have 97 cells
# Processing experiment 501021421
# In this experiment, we have 237 cells, but after filtering, we have 44 cells
# In this experiment, we have 237 cells, but after filtering and removing negative mean dffs, we have 44 cells
# Processing experiment 547388708
# In this experiment, we have 177 cells, but after filtering, we have 46 cells
# In this experiment, we have 177 cells, but after filtering and removing negative mean dffs, we have 46 cells
# Processing experiment 660513003
# In this experiment, we have 254 cells, but after filtering, we have 62 cells
# In this experiment, we have 254 cells, but after filtering and removing negative mean dffs, we have 62 cells
# Processing experiment 508356957
# In this experiment, we have 303 cells, but after filtering, we have 56 cells
# In this experiment, we have 303 cells, but after filtering and removing negative mean dffs, we have 56 cells
# Processing experiment 712178511
# In this experiment, we have 307 cells, but after filtering, we have 76 cells
# In this experiment, we have 307 cells, but after filtering and removing negative mean dffs, we have 76 cells
# Processing experiment 531134090
# In this experiment, we have 123 cells, but after filtering, we have 12 cells
# In this experiment, we have 123 cells, but after filtering and removing negative mean dffs, we have 12 cells
# Processing experiment 512270518
# In this experiment, we have 122 cells, but after filtering, we have 28 cells
# In this experiment, we have 122 cells, but after filtering and removing negative mean dffs, we have 28 cells
# Processing experiment 658536111
# In this experiment, we have 280 cells, but after filtering, we have 75 cells
# In this experiment, we have 280 cells, but after filtering and removing negative mean dffs, we have 75 cells
# Processing experiment 647155122
# In this experiment, we have 284 cells, but after filtering, we have 77 cells
# In this experiment, we have 284 cells, but after filtering and removing negative mean dffs, we have 77 cells
# Processing experiment 502608215
# In this experiment, we have 391 cells, but after filtering, we have 145 cells
# In this experiment, we have 391 cells, but after filtering and removing negative mean dffs, we have 145 cells
# Processing experiment 527048992
# In this experiment, we have 270 cells, but after filtering, we have 93 cells
# In this experiment, we have 270 cells, but after filtering and removing negative mean dffs, we have 93 cells
# VISp [275, 335, 350] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Rorb-IRES2-Cre', 'Scnn1a-Tg3-Cre'] #Experiments:  34 #Cells: 2626 circ var: 0.9365499652224593
# There are 26 experiments for  VISp [375, 390, 400] ['Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Fezf2-CreER', 'Rbp4-Cre_KL100', 'Tlx3-Cre_PL56']
# Processing experiment 662033243
# In this experiment, we have 192 cells, but after filtering, we have 44 cells
# In this experiment, we have 192 cells, but after filtering and removing negative mean dffs, we have 44 cells
# Processing experiment 546716391
# In this experiment, we have 217 cells, but after filtering, we have 41 cells
# In this experiment, we have 217 cells, but after filtering and removing negative mean dffs, we have 41 cells
# Processing experiment 649401936
# In this experiment, we have 83 cells, but after filtering, we have 25 cells
# In this experiment, we have 83 cells, but after filtering and removing negative mean dffs, we have 25 cells
# Processing experiment 643645390
# In this experiment, we have 180 cells, but after filtering, we have 39 cells
# In this experiment, we have 180 cells, but after filtering and removing negative mean dffs, we have 39 cells
# Processing experiment 502962794
# In this experiment, we have 123 cells, but after filtering, we have 22 cells
# In this experiment, we have 123 cells, but after filtering and removing negative mean dffs, we have 22 cells
# Processing experiment 649938038
# In this experiment, we have 226 cells, but after filtering, we have 45 cells
# In this experiment, we have 226 cells, but after filtering and removing negative mean dffs, we have 45 cells
# Processing experiment 571137446
# In this experiment, we have 66 cells, but after filtering, we have 19 cells
# In this experiment, we have 66 cells, but after filtering and removing negative mean dffs, we have 19 cells
# Processing experiment 637671554
# In this experiment, we have 268 cells, but after filtering, we have 59 cells
# In this experiment, we have 268 cells, but after filtering and removing negative mean dffs, we have 59 cells
# Processing experiment 595806300
# In this experiment, we have 192 cells, but after filtering, we have 44 cells
# In this experiment, we have 192 cells, but after filtering and removing negative mean dffs, we have 44 cells
# Processing experiment 541010698
# In this experiment, we have 334 cells, but after filtering, we have 79 cells
# In this experiment, we have 334 cells, but after filtering and removing negative mean dffs, we have 79 cells
# Processing experiment 674679019
# In this experiment, we have 109 cells, but after filtering, we have 33 cells
# In this experiment, we have 109 cells, but after filtering and removing negative mean dffs, we have 33 cells
# Processing experiment 664404274
# In this experiment, we have 200 cells, but after filtering, we have 39 cells
# In this experiment, we have 200 cells, but after filtering and removing negative mean dffs, we have 39 cells
# Processing experiment 598564173
# In this experiment, we have 41 cells, but after filtering, we have 11 cells
# In this experiment, we have 41 cells, but after filtering and removing negative mean dffs, we have 11 cells
# Processing experiment 637998955
# In this experiment, we have 125 cells, but after filtering, we have 33 cells
# In this experiment, we have 125 cells, but after filtering and removing negative mean dffs, we have 33 cells
# Processing experiment 623347352
# In this experiment, we have 77 cells, but after filtering, we have 14 cells
# In this experiment, we have 77 cells, but after filtering and removing negative mean dffs, we have 14 cells
# Processing experiment 637669270
# In this experiment, we have 164 cells, but after filtering, we have 21 cells
# In this experiment, we have 164 cells, but after filtering and removing negative mean dffs, we have 21 cells
# Processing experiment 657016267
# In this experiment, we have 205 cells, but after filtering, we have 26 cells
# In this experiment, we have 205 cells, but after filtering and removing negative mean dffs, we have 26 cells
# Processing experiment 595263154
# In this experiment, we have 356 cells, but after filtering, we have 45 cells
# In this experiment, we have 356 cells, but after filtering and removing negative mean dffs, we have 45 cells
# Processing experiment 657082055
# In this experiment, we have 360 cells, but after filtering, we have 79 cells
# In this experiment, we have 360 cells, but after filtering and removing negative mean dffs, we have 79 cells
# Processing experiment 559192380
# In this experiment, we have 89 cells, but after filtering, we have 21 cells
# In this experiment, we have 89 cells, but after filtering and removing negative mean dffs, we have 21 cells
# Processing experiment 617381605
# In this experiment, we have 138 cells, but after filtering, we have 35 cells
# In this experiment, we have 138 cells, but after filtering and removing negative mean dffs, we have 35 cells
# Processing experiment 662974315
# In this experiment, we have 126 cells, but after filtering, we have 25 cells
# In this experiment, we have 126 cells, but after filtering and removing negative mean dffs, we have 25 cells
# Processing experiment 592407200
# In this experiment, we have 27 cells, but after filtering, we have 4 cells
# In this experiment, we have 27 cells, but after filtering and removing negative mean dffs, we have 4 cells
# Processing experiment 643592303
# In this experiment, we have 96 cells, but after filtering, we have 20 cells
# In this experiment, we have 96 cells, but after filtering and removing negative mean dffs, we have 20 cells
# Processing experiment 653932505
# In this experiment, we have 407 cells, but after filtering, we have 57 cells
# In this experiment, we have 407 cells, but after filtering and removing negative mean dffs, we have 57 cells
# Processing experiment 637115675
# In this experiment, we have 29 cells, but after filtering, we have 11 cells
# In this experiment, we have 29 cells, but after filtering and removing negative mean dffs, we have 11 cells
# VISp [375, 390, 400] ['Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Fezf2-CreER', 'Rbp4-Cre_KL100', 'Tlx3-Cre_PL56'] #Experiments:  26 #Cells: 891 circ var: 0.9328711878652404
# There are 6 experiments for  VISp [550] ['Ntsr1-Cre_GN220']
# Processing experiment 665722301
# In this experiment, we have 28 cells, but after filtering, we have 3 cells
# In this experiment, we have 28 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 689388034
# In this experiment, we have 214 cells, but after filtering, we have 39 cells
# In this experiment, we have 214 cells, but after filtering and removing negative mean dffs, we have 39 cells
# Processing experiment 604145810
# In this experiment, we have 65 cells, but after filtering, we have 11 cells
# In this experiment, we have 65 cells, but after filtering and removing negative mean dffs, we have 11 cells
# Processing experiment 603576132
# In this experiment, we have 163 cells, but after filtering, we have 41 cells
# In this experiment, we have 163 cells, but after filtering and removing negative mean dffs, we have 41 cells
# Processing experiment 645086975
# In this experiment, we have 69 cells, but after filtering, we have 12 cells
# In this experiment, we have 69 cells, but after filtering and removing negative mean dffs, we have 12 cells
# Processing experiment 627823695
# In this experiment, we have 34 cells, but after filtering, we have 10 cells
# In this experiment, we have 34 cells, but after filtering and removing negative mean dffs, we have 10 cells
# VISp [550] ['Ntsr1-Cre_GN220'] #Experiments:  6 #Cells: 116 circ var: 0.9861644315835648
# There are 13 experiments for  VISp [175, 185, 195, 200, 225, 275] ['Pvalb-IRES-Cre']
# Processing experiment 673171528
# In this experiment, we have 17 cells, but after filtering, we have 0 cells
# In this experiment, we have 17 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 712178483
# In this experiment, we have 12 cells, but after filtering, we have 0 cells
# In this experiment, we have 12 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 671618887
# In this experiment, we have 28 cells, but after filtering, we have 0 cells
# In this experiment, we have 28 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 669861524
# In this experiment, we have 22 cells, but after filtering, we have 0 cells
# In this experiment, we have 22 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 672206735
# In this experiment, we have 13 cells, but after filtering, we have 0 cells
# In this experiment, we have 13 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 676503588
# In this experiment, we have 40 cells, but after filtering, we have 0 cells
# In this experiment, we have 40 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 672211004
# In this experiment, we have 17 cells, but after filtering, we have 0 cells
# In this experiment, we have 17 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 670395999
# In this experiment, we have 3 cells, but after filtering, we have 0 cells
# In this experiment, we have 3 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 671164733
# In this experiment, we have 49 cells, but after filtering, we have 0 cells
# In this experiment, we have 49 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 675477919
# In this experiment, we have 11 cells, but after filtering, we have 0 cells
# In this experiment, we have 11 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 692345003
# In this experiment, we have 14 cells, but after filtering, we have 0 cells
# In this experiment, we have 14 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 673914981
# In this experiment, we have 19 cells, but after filtering, we have 0 cells
# In this experiment, we have 19 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 670728674
# In this experiment, we have 28 cells, but after filtering, we have 0 cells
# In this experiment, we have 28 cells, but after filtering and removing negative mean dffs, we have 0 cells
# There are 17 experiments for  VISp [175, 275] ['Vip-IRES-Cre']
# Processing experiment 663479824
# In this experiment, we have 11 cells, but after filtering, we have 0 cells
# In this experiment, we have 11 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 662361096
# In this experiment, we have 28 cells, but after filtering, we have 4 cells
# In this experiment, we have 28 cells, but after filtering and removing negative mean dffs, we have 4 cells
# Processing experiment 657078119
# In this experiment, we have 16 cells, but after filtering, we have 0 cells
# In this experiment, we have 16 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 652091264
# In this experiment, we have 24 cells, but after filtering, we have 1 cells
# In this experiment, we have 24 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 657390171
# In this experiment, we have 11 cells, but after filtering, we have 1 cells
# In this experiment, we have 11 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 652842495
# In this experiment, we have 5 cells, but after filtering, we have 0 cells
# In this experiment, we have 5 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 657389972
# In this experiment, we have 7 cells, but after filtering, we have 0 cells
# In this experiment, we have 7 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 612543999
# In this experiment, we have 20 cells, but after filtering, we have 0 cells
# In this experiment, we have 20 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 658518486
# In this experiment, we have 14 cells, but after filtering, we have 0 cells
# In this experiment, we have 14 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 659495103
# In this experiment, we have 89 cells, but after filtering, we have 1 cells
# In this experiment, we have 89 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 657650110
# In this experiment, we have 20 cells, but after filtering, we have 3 cells
# In this experiment, we have 20 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 583279803
# In this experiment, we have 14 cells, but after filtering, we have 1 cells
# In this experiment, we have 14 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 585900296
# In this experiment, we have 14 cells, but after filtering, we have 1 cells
# In this experiment, we have 14 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 650079244
# In this experiment, we have 32 cells, but after filtering, we have 0 cells
# In this experiment, we have 32 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 606353987
# In this experiment, we have 17 cells, but after filtering, we have 0 cells
# In this experiment, we have 17 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 617395455
# In this experiment, we have 21 cells, but after filtering, we have 1 cells
# In this experiment, we have 21 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 657775947
# In this experiment, we have 9 cells, but after filtering, we have 0 cells
# In this experiment, we have 9 cells, but after filtering and removing negative mean dffs, we have 0 cells
# VISp [175, 275] ['Vip-IRES-Cre'] #Experiments:  8 #Cells: 13 circ var: 0.9085410291420253
# There are 4 experiments for  VISp [265, 285, 350] ['Sst-IRES-Cre']
# Processing experiment 576095926
# In this experiment, we have 19 cells, but after filtering, we have 2 cells
# In this experiment, we have 19 cells, but after filtering and removing negative mean dffs, we have 2 cells
# Processing experiment 575939366
# In this experiment, we have 11 cells, but after filtering, we have 0 cells
# In this experiment, we have 11 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 612044635
# In this experiment, we have 27 cells, but after filtering, we have 1 cells
# In this experiment, we have 27 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 582918858
# In this experiment, we have 18 cells, but after filtering, we have 5 cells
# In this experiment, we have 18 cells, but after filtering and removing negative mean dffs, we have 5 cells
# VISp [265, 285, 350] ['Sst-IRES-Cre'] #Experiments:  3 #Cells: 8 circ var: 0.8005644311558472
# There are 10 experiments for  VISal [175, 265] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre']
# Processing experiment 605859367
# In this experiment, we have 64 cells, but after filtering, we have 8 cells
# In this experiment, we have 64 cells, but after filtering and removing negative mean dffs, we have 8 cells
# Processing experiment 506773892
# In this experiment, we have 142 cells, but after filtering, we have 16 cells
# In this experiment, we have 142 cells, but after filtering and removing negative mean dffs, we have 16 cells
# Processing experiment 563176332
# In this experiment, we have 346 cells, but after filtering, we have 93 cells
# In this experiment, we have 346 cells, but after filtering and removing negative mean dffs, we have 93 cells
# Processing experiment 562052595
# In this experiment, we have 209 cells, but after filtering, we have 38 cells
# In this experiment, we have 209 cells, but after filtering and removing negative mean dffs, we have 38 cells
# Processing experiment 560898462
# In this experiment, we have 303 cells, but after filtering, we have 32 cells
# In this experiment, we have 303 cells, but after filtering and removing negative mean dffs, we have 32 cells
# Processing experiment 557225279
# In this experiment, we have 98 cells, but after filtering, we have 7 cells
# In this experiment, we have 98 cells, but after filtering and removing negative mean dffs, we have 7 cells
# Processing experiment 503412730
# In this experiment, we have 161 cells, but after filtering, we have 24 cells
# In this experiment, we have 161 cells, but after filtering and removing negative mean dffs, we have 24 cells
# Processing experiment 502199136
# In this experiment, we have 250 cells, but after filtering, we have 27 cells
# In this experiment, we have 250 cells, but after filtering and removing negative mean dffs, we have 27 cells
# Processing experiment 501876401
# In this experiment, we have 260 cells, but after filtering, we have 42 cells
# In this experiment, we have 260 cells, but after filtering and removing negative mean dffs, we have 42 cells
# Processing experiment 501933264
# In this experiment, we have 315 cells, but after filtering, we have 57 cells
# In this experiment, we have 315 cells, but after filtering and removing negative mean dffs, we have 57 cells
# VISal [175, 265] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre'] #Experiments:  10 #Cells: 344 circ var: 0.9265298628765756
# There are 1 experiments for  VISal [275] ['Sst-IRES-Cre']
# Processing experiment 589441079
# In this experiment, we have 24 cells, but after filtering, we have 3 cells
# In this experiment, we have 24 cells, but after filtering and removing negative mean dffs, we have 3 cells
# VISal [275] ['Sst-IRES-Cre'] #Experiments:  1 #Cells: 3 circ var: 0.9073602825248439
# There are 21 experiments for  VISal [275, 276, 300, 350] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre']
# Processing experiment 510390912
# In this experiment, we have 161 cells, but after filtering, we have 22 cells
# In this experiment, we have 161 cells, but after filtering and removing negative mean dffs, we have 22 cells
# Processing experiment 685816006
# In this experiment, we have 47 cells, but after filtering, we have 14 cells
# In this experiment, we have 47 cells, but after filtering and removing negative mean dffs, we have 14 cells
# Processing experiment 504853580
# In this experiment, we have 208 cells, but after filtering, we have 29 cells
# In this experiment, we have 208 cells, but after filtering and removing negative mean dffs, we have 29 cells
# Processing experiment 548379748
# In this experiment, we have 39 cells, but after filtering, we have 7 cells
# In this experiment, we have 39 cells, but after filtering and removing negative mean dffs, we have 7 cells
# Processing experiment 512326618
# In this experiment, we have 275 cells, but after filtering, we have 103 cells
# In this experiment, we have 275 cells, but after filtering and removing negative mean dffs, we have 103 cells
# Processing experiment 505407318
# In this experiment, we have 279 cells, but after filtering, we have 50 cells
# In this experiment, we have 279 cells, but after filtering and removing negative mean dffs, we have 50 cells
# Processing experiment 561472633
# In this experiment, we have 492 cells, but after filtering, we have 123 cells
# In this experiment, we have 492 cells, but after filtering and removing negative mean dffs, we have 123 cells
# Processing experiment 627823344
# In this experiment, we have 243 cells, but after filtering, we have 54 cells
# In this experiment, we have 243 cells, but after filtering and removing negative mean dffs, we have 54 cells
# Processing experiment 595183197
# In this experiment, we have 1 cells, but after filtering, we have 0 cells
# In this experiment, we have 1 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 591460070
# In this experiment, we have 340 cells, but after filtering, we have 56 cells
# In this experiment, we have 340 cells, but after filtering and removing negative mean dffs, we have 56 cells
# Processing experiment 558670888
# In this experiment, we have 264 cells, but after filtering, we have 63 cells
# In this experiment, we have 264 cells, but after filtering and removing negative mean dffs, we have 63 cells
# Processing experiment 569396924
# In this experiment, we have 129 cells, but after filtering, we have 30 cells
# In this experiment, we have 129 cells, but after filtering and removing negative mean dffs, we have 30 cells
# Processing experiment 639931541
# In this experiment, we have 310 cells, but after filtering, we have 39 cells
# In this experiment, we have 310 cells, but after filtering and removing negative mean dffs, we have 39 cells
# Processing experiment 559382012
# In this experiment, we have 48 cells, but after filtering, we have 9 cells
# In this experiment, we have 48 cells, but after filtering and removing negative mean dffs, we have 9 cells
# Processing experiment 509904120
# In this experiment, we have 69 cells, but after filtering, we have 3 cells
# In this experiment, we have 69 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 507464107
# In this experiment, we have 265 cells, but after filtering, we have 36 cells
# In this experiment, we have 265 cells, but after filtering and removing negative mean dffs, we have 36 cells
# Processing experiment 555042467
# In this experiment, we have 78 cells, but after filtering, we have 17 cells
# In this experiment, we have 78 cells, but after filtering and removing negative mean dffs, we have 17 cells
# Processing experiment 512164988
# In this experiment, we have 339 cells, but after filtering, we have 108 cells
# In this experiment, we have 339 cells, but after filtering and removing negative mean dffs, we have 108 cells
# Processing experiment 638056634
# In this experiment, we have 212 cells, but after filtering, we have 53 cells
# In this experiment, we have 212 cells, but after filtering and removing negative mean dffs, we have 53 cells
# Processing experiment 505695962
# In this experiment, we have 335 cells, but after filtering, we have 62 cells
# In this experiment, we have 335 cells, but after filtering and removing negative mean dffs, we have 62 cells
# Processing experiment 638862121
# In this experiment, we have 7 cells, but after filtering, we have 2 cells
# In this experiment, we have 7 cells, but after filtering and removing negative mean dffs, we have 2 cells
# VISal [275, 276, 300, 350] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre'] #Experiments:  20 #Cells: 880 circ var: 0.9604614646564652
# There are 9 experiments for  VISal [365, 375] ['Emx1-IRES-Cre', 'Rbp4-Cre_KL100']
# Processing experiment 588483711
# In this experiment, we have 51 cells, but after filtering, we have 5 cells
# In this experiment, we have 51 cells, but after filtering and removing negative mean dffs, we have 5 cells
# Processing experiment 504568756
# In this experiment, we have 187 cells, but after filtering, we have 34 cells
# In this experiment, we have 187 cells, but after filtering and removing negative mean dffs, we have 34 cells
# Processing experiment 573083539
# In this experiment, we have 66 cells, but after filtering, we have 11 cells
# In this experiment, we have 66 cells, but after filtering and removing negative mean dffs, we have 11 cells
# Processing experiment 511440894
# In this experiment, we have 101 cells, but after filtering, we have 7 cells
# In this experiment, we have 101 cells, but after filtering and removing negative mean dffs, we have 7 cells
# Processing experiment 569299884
# In this experiment, we have 99 cells, but after filtering, we have 11 cells
# In this experiment, we have 99 cells, but after filtering and removing negative mean dffs, we have 11 cells
# Processing experiment 563710064
# In this experiment, we have 162 cells, but after filtering, we have 13 cells
# In this experiment, we have 162 cells, but after filtering and removing negative mean dffs, we have 13 cells
# Processing experiment 572722662
# In this experiment, we have 8 cells, but after filtering, we have 3 cells
# In this experiment, we have 8 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 584944065
# In this experiment, we have 28 cells, but after filtering, we have 4 cells
# In this experiment, we have 28 cells, but after filtering and removing negative mean dffs, we have 4 cells
# Processing experiment 562536153
# In this experiment, we have 176 cells, but after filtering, we have 25 cells
# In this experiment, we have 176 cells, but after filtering and removing negative mean dffs, we have 25 cells
# VISal [365, 375] ['Emx1-IRES-Cre', 'Rbp4-Cre_KL100'] #Experiments:  9 #Cells: 113 circ var: 0.9670154985318425
# There are 8 experiments for  VISam [175] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre']
# Processing experiment 565216523
# In this experiment, we have 197 cells, but after filtering, we have 13 cells
# In this experiment, we have 197 cells, but after filtering and removing negative mean dffs, we have 13 cells
# Processing experiment 571177441
# In this experiment, we have 164 cells, but after filtering, we have 24 cells
# In this experiment, we have 164 cells, but after filtering and removing negative mean dffs, we have 24 cells
# Processing experiment 707006626
# In this experiment, we have 75 cells, but after filtering, we have 6 cells
# In this experiment, we have 75 cells, but after filtering and removing negative mean dffs, we have 6 cells
# Processing experiment 557304694
# In this experiment, we have 130 cells, but after filtering, we have 5 cells
# In this experiment, we have 130 cells, but after filtering and removing negative mean dffs, we have 5 cells
# Processing experiment 637669284
# In this experiment, we have 133 cells, but after filtering, we have 17 cells
# In this experiment, we have 133 cells, but after filtering and removing negative mean dffs, we have 17 cells
# Processing experiment 613599811
# In this experiment, we have 102 cells, but after filtering, we have 5 cells
# In this experiment, we have 102 cells, but after filtering and removing negative mean dffs, we have 5 cells
# Processing experiment 569739027
# In this experiment, we have 53 cells, but after filtering, we have 1 cells
# In this experiment, we have 53 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 566458505
# In this experiment, we have 167 cells, but after filtering, we have 11 cells
# In this experiment, we have 167 cells, but after filtering and removing negative mean dffs, we have 11 cells
# VISam [175] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre'] #Experiments:  8 #Cells: 82 circ var: 0.9601781354266874
# There are 21 experiments for  VISam [275, 320, 325, 350] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre']
# Processing experiment 556665481
# In this experiment, we have 7 cells, but after filtering, we have 0 cells
# In this experiment, we have 7 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 712919665
# In this experiment, we have 46 cells, but after filtering, we have 1 cells
# In this experiment, we have 46 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 571103671
# In this experiment, we have 195 cells, but after filtering, we have 6 cells
# In this experiment, we have 195 cells, but after filtering and removing negative mean dffs, we have 6 cells
# Processing experiment 560027980
# In this experiment, we have 28 cells, but after filtering, we have 1 cells
# In this experiment, we have 28 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 556344224
# In this experiment, we have 75 cells, but after filtering, we have 11 cells
# In this experiment, we have 75 cells, but after filtering and removing negative mean dffs, we have 11 cells
# Processing experiment 569457162
# In this experiment, we have 58 cells, but after filtering, we have 4 cells
# In this experiment, we have 58 cells, but after filtering and removing negative mean dffs, we have 4 cells
# Processing experiment 570305847
# In this experiment, we have 261 cells, but after filtering, we have 19 cells
# In this experiment, we have 261 cells, but after filtering and removing negative mean dffs, we have 19 cells
# Processing experiment 566307038
# In this experiment, we have 297 cells, but after filtering, we have 47 cells
# In this experiment, we have 297 cells, but after filtering and removing negative mean dffs, we have 47 cells
# Processing experiment 562711440
# In this experiment, we have 50 cells, but after filtering, we have 4 cells
# In this experiment, we have 50 cells, but after filtering and removing negative mean dffs, we have 4 cells
# Processing experiment 551834174
# In this experiment, we have 66 cells, but after filtering, we have 17 cells
# In this experiment, we have 66 cells, but after filtering and removing negative mean dffs, we have 17 cells
# Processing experiment 710469199
# In this experiment, we have 163 cells, but after filtering, we have 30 cells
# In this experiment, we have 163 cells, but after filtering and removing negative mean dffs, we have 30 cells
# Processing experiment 611638995
# In this experiment, we have 118 cells, but after filtering, we have 18 cells
# In this experiment, we have 118 cells, but after filtering and removing negative mean dffs, we have 18 cells
# Processing experiment 552760671
# In this experiment, we have 241 cells, but after filtering, we have 40 cells
# In this experiment, we have 241 cells, but after filtering and removing negative mean dffs, we have 40 cells
# Processing experiment 565698388
# In this experiment, we have 5 cells, but after filtering, we have 0 cells
# In this experiment, we have 5 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 576411246
# In this experiment, we have 20 cells, but after filtering, we have 2 cells
# In this experiment, we have 20 cells, but after filtering and removing negative mean dffs, we have 2 cells
# Processing experiment 595229536
# In this experiment, we have 148 cells, but after filtering, we have 24 cells
# In this experiment, we have 148 cells, but after filtering and removing negative mean dffs, we have 24 cells
# Processing experiment 638262558
# In this experiment, we have 6 cells, but after filtering, we have 1 cells
# In this experiment, we have 6 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 550851591
# In this experiment, we have 121 cells, but after filtering, we have 14 cells
# In this experiment, we have 121 cells, but after filtering and removing negative mean dffs, we have 14 cells
# Processing experiment 605606109
# In this experiment, we have 71 cells, but after filtering, we have 18 cells
# In this experiment, we have 71 cells, but after filtering and removing negative mean dffs, we have 18 cells
# Processing experiment 652094917
# In this experiment, we have 82 cells, but after filtering, we have 12 cells
# In this experiment, we have 82 cells, but after filtering and removing negative mean dffs, we have 12 cells
# Processing experiment 569718097
# In this experiment, we have 40 cells, but after filtering, we have 3 cells
# In this experiment, we have 40 cells, but after filtering and removing negative mean dffs, we have 3 cells
# VISam [275, 320, 325, 350] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre'] #Experiments:  19 #Cells: 272 circ var: 0.8919765148579433
# There are 9 experiments for  VISam [375] ['Emx1-IRES-Cre', 'Rbp4-Cre_KL100']
# Processing experiment 556353209
# In this experiment, we have 37 cells, but after filtering, we have 2 cells
# In this experiment, we have 37 cells, but after filtering and removing negative mean dffs, we have 2 cells
# Processing experiment 647603932
# In this experiment, we have 45 cells, but after filtering, we have 2 cells
# In this experiment, we have 45 cells, but after filtering and removing negative mean dffs, we have 2 cells
# Processing experiment 601904502
# In this experiment, we have 23 cells, but after filtering, we have 4 cells
# In this experiment, we have 23 cells, but after filtering and removing negative mean dffs, we have 4 cells
# Processing experiment 616779893
# In this experiment, we have 21 cells, but after filtering, we have 3 cells
# In this experiment, we have 21 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 569792817
# In this experiment, we have 95 cells, but after filtering, we have 7 cells
# In this experiment, we have 95 cells, but after filtering and removing negative mean dffs, we have 7 cells
# Processing experiment 642884591
# In this experiment, we have 33 cells, but after filtering, we have 3 cells
# In this experiment, we have 33 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 578674360
# In this experiment, we have 60 cells, but after filtering, we have 11 cells
# In this experiment, we have 60 cells, but after filtering and removing negative mean dffs, we have 11 cells
# Processing experiment 575302108
# In this experiment, we have 40 cells, but after filtering, we have 8 cells
# In this experiment, we have 40 cells, but after filtering and removing negative mean dffs, we have 8 cells
# Processing experiment 595273803
# In this experiment, we have 96 cells, but after filtering, we have 11 cells
# In this experiment, we have 96 cells, but after filtering and removing negative mean dffs, we have 11 cells
# VISam [375] ['Emx1-IRES-Cre', 'Rbp4-Cre_KL100'] #Experiments:  9 #Cells: 51 circ var: 0.9452266637493075
# There are 17 experiments for  VISl [175] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre']
# Processing experiment 564425777
# In this experiment, we have 347 cells, but after filtering, we have 66 cells
# In this experiment, we have 347 cells, but after filtering and removing negative mean dffs, we have 66 cells
# Processing experiment 502793808
# In this experiment, we have 263 cells, but after filtering, we have 48 cells
# In this experiment, we have 263 cells, but after filtering and removing negative mean dffs, we have 48 cells
# Processing experiment 501940850
# In this experiment, we have 234 cells, but after filtering, we have 38 cells
# In this experiment, we have 234 cells, but after filtering and removing negative mean dffs, we have 38 cells
# Processing experiment 560926639
# In this experiment, we have 172 cells, but after filtering, we have 22 cells
# In this experiment, we have 172 cells, but after filtering and removing negative mean dffs, we have 22 cells
# Processing experiment 550455111
# In this experiment, we have 269 cells, but after filtering, we have 26 cells
# In this experiment, we have 269 cells, but after filtering and removing negative mean dffs, we have 26 cells
# Processing experiment 506030579
# In this experiment, we have 153 cells, but after filtering, we have 13 cells
# In this experiment, we have 153 cells, but after filtering and removing negative mean dffs, we have 13 cells
# Processing experiment 653551965
# In this experiment, we have 80 cells, but after filtering, we have 7 cells
# In this experiment, we have 80 cells, but after filtering and removing negative mean dffs, we have 7 cells
# Processing experiment 647595665
# In this experiment, we have 166 cells, but after filtering, we have 32 cells
# In this experiment, we have 166 cells, but after filtering and removing negative mean dffs, we have 32 cells
# Processing experiment 557848210
# In this experiment, we have 256 cells, but after filtering, we have 52 cells
# In this experiment, we have 256 cells, but after filtering and removing negative mean dffs, we have 52 cells
# Processing experiment 645700487
# In this experiment, we have 90 cells, but after filtering, we have 5 cells
# In this experiment, we have 90 cells, but after filtering and removing negative mean dffs, we have 5 cells
# Processing experiment 662358771
# In this experiment, we have 96 cells, but after filtering, we have 9 cells
# In this experiment, we have 96 cells, but after filtering and removing negative mean dffs, we have 9 cells
# Processing experiment 506809539
# In this experiment, we have 248 cells, but after filtering, we have 55 cells
# In this experiment, we have 248 cells, but after filtering and removing negative mean dffs, we have 55 cells
# Processing experiment 552410386
# In this experiment, we have 144 cells, but after filtering, we have 9 cells
# In this experiment, we have 144 cells, but after filtering and removing negative mean dffs, we have 9 cells
# Processing experiment 652737867
# In this experiment, we have 219 cells, but after filtering, we have 17 cells
# In this experiment, we have 219 cells, but after filtering and removing negative mean dffs, we have 17 cells
# Processing experiment 651770186
# In this experiment, we have 360 cells, but after filtering, we have 31 cells
# In this experiment, we have 360 cells, but after filtering and removing negative mean dffs, we have 31 cells
# Processing experiment 583136567
# In this experiment, we have 78 cells, but after filtering, we have 8 cells
# In this experiment, we have 78 cells, but after filtering and removing negative mean dffs, we have 8 cells
# Processing experiment 707923645
# In this experiment, we have 270 cells, but after filtering, we have 61 cells
# In this experiment, we have 270 cells, but after filtering and removing negative mean dffs, we have 61 cells
# VISl [175] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre'] #Experiments:  17 #Cells: 499 circ var: 0.991090090211689
# There are 25 experiments for  VISl [275, 325, 350] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre']
# Processing experiment 653123929
# In this experiment, we have 406 cells, but after filtering, we have 83 cells
# In this experiment, we have 406 cells, but after filtering and removing negative mean dffs, we have 83 cells
# Processing experiment 585035184
# In this experiment, we have 148 cells, but after filtering, we have 30 cells
# In this experiment, we have 148 cells, but after filtering and removing negative mean dffs, we have 30 cells
# Processing experiment 546641574
# In this experiment, we have 255 cells, but after filtering, we have 48 cells
# In this experiment, we have 255 cells, but after filtering and removing negative mean dffs, we have 48 cells
# Processing experiment 507129766
# In this experiment, we have 119 cells, but after filtering, we have 8 cells
# In this experiment, we have 119 cells, but after filtering and removing negative mean dffs, we have 8 cells
# Processing experiment 558476282
# In this experiment, we have 140 cells, but after filtering, we have 6 cells
# In this experiment, we have 140 cells, but after filtering and removing negative mean dffs, we have 6 cells
# Processing experiment 654532828
# In this experiment, we have 156 cells, but after filtering, we have 18 cells
# In this experiment, we have 156 cells, but after filtering and removing negative mean dffs, we have 18 cells
# Processing experiment 682049099
# In this experiment, we have 50 cells, but after filtering, we have 3 cells
# In this experiment, we have 50 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 672207947
# In this experiment, we have 330 cells, but after filtering, we have 104 cells
# In this experiment, we have 330 cells, but after filtering and removing negative mean dffs, we have 104 cells
# Processing experiment 645256361
# In this experiment, we have 197 cells, but after filtering, we have 38 cells
# In this experiment, we have 197 cells, but after filtering and removing negative mean dffs, we have 38 cells
# Processing experiment 511573879
# In this experiment, we have 190 cells, but after filtering, we have 40 cells
# In this experiment, we have 190 cells, but after filtering and removing negative mean dffs, we have 40 cells
# Processing experiment 662348804
# In this experiment, we have 235 cells, but after filtering, we have 76 cells
# In this experiment, we have 235 cells, but after filtering and removing negative mean dffs, we have 76 cells
# Processing experiment 699155265
# In this experiment, we have 184 cells, but after filtering, we have 31 cells
# ...
# There are 3 experiments for  VISpm [550] ['Ntsr1-Cre_GN220']
# Processing experiment 637126541
# In this experiment, we have 28 cells, but after filtering, we have 5 cells
# In this experiment, we have 28 cells, but after filtering and removing negative mean dffs, we have 5 cells
# Processing experiment 604529230
# In this experiment, we have 143 cells, but after filtering, we have 18 cells
# In this experiment, we have 143 cells, but after filtering and removing negative mean dffs, we have 18 cells
# Processing experiment 647595671
# In this experiment, we have 159 cells, but after filtering, we have 13 cells
# In this experiment, we have 159 cells, but after filtering and removing negative mean dffs, we have 13 cells
# VISpm [550] ['Ntsr1-Cre_GN220'] #Experiments:  3 #Cells: 36 circ var: 0.9003742133090108
# There are 16 experiments for  VISpm [175, 275] ['Vip-IRES-Cre']
# Processing experiment 626027944
# In this experiment, we have 10 cells, but after filtering, we have 3 cells
# In this experiment, we have 10 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 649324898
# In this experiment, we have 16 cells, but after filtering, we have 5 cells
# In this experiment, we have 16 cells, but after filtering and removing negative mean dffs, we have 5 cells
# Processing experiment 692345336
# In this experiment, we have 35 cells, but after filtering, we have 1 cells
# In this experiment, we have 35 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 647598519
# In this experiment, we have 20 cells, but after filtering, we have 7 cells
# In this experiment, we have 20 cells, but after filtering and removing negative mean dffs, we have 7 cells
# Processing experiment 696156783
# In this experiment, we have 37 cells, but after filtering, we have 2 cells
# In this experiment, we have 37 cells, but after filtering and removing negative mean dffs, we have 2 cells
# Processing experiment 651770380
# In this experiment, we have 23 cells, but after filtering, we have 11 cells
# In this experiment, we have 23 cells, but after filtering and removing negative mean dffs, we have 11 cells
# Processing experiment 658020691
# In this experiment, we have 16 cells, but after filtering, we have 1 cells
# In this experiment, we have 16 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 609517556
# In this experiment, we have 19 cells, but after filtering, we have 4 cells
# In this experiment, we have 19 cells, but after filtering and removing negative mean dffs, we have 4 cells
# Processing experiment 643066628
# In this experiment, we have 25 cells, but after filtering, we have 0 cells
# In this experiment, we have 25 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 686909240
# In this experiment, we have 60 cells, but after filtering, we have 3 cells
# In this experiment, we have 60 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 617388117
# In this experiment, we have 10 cells, but after filtering, we have 0 cells
# In this experiment, we have 10 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 691197571
# In this experiment, we have 26 cells, but after filtering, we have 3 cells
# In this experiment, we have 26 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 652989442
# In this experiment, we have 22 cells, but after filtering, we have 4 cells
# In this experiment, we have 22 cells, but after filtering and removing negative mean dffs, we have 4 cells
# Processing experiment 601705404
# In this experiment, we have 23 cells, but after filtering, we have 4 cells
# In this experiment, we have 23 cells, but after filtering and removing negative mean dffs, we have 4 cells
# Processing experiment 657776356
# In this experiment, we have 10 cells, but after filtering, we have 1 cells
# In this experiment, we have 10 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 649409874
# In this experiment, we have 35 cells, but after filtering, we have 2 cells
# In this experiment, we have 35 cells, but after filtering and removing negative mean dffs, we have 2 cells
# VISpm [175, 275] ['Vip-IRES-Cre'] #Experiments:  14 #Cells: 51 circ var: 0.8471297656761843
# There are 14 experiments for  VISpm [275, 300, 325, 350, 375] ['Sst-IRES-Cre']
# Processing experiment 603763073
# In this experiment, we have 27 cells, but after filtering, we have 3 cells
# In this experiment, we have 27 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 639117196
# In this experiment, we have 13 cells, but after filtering, we have 1 cells
# In this experiment, we have 13 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 639251932
# In this experiment, we have 20 cells, but after filtering, we have 5 cells
# In this experiment, we have 20 cells, but after filtering and removing negative mean dffs, we have 5 cells
# Processing experiment 599909878
# In this experiment, we have 19 cells, but after filtering, we have 3 cells
# In this experiment, we have 19 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 603188560
# In this experiment, we have 11 cells, but after filtering, we have 1 cells
# In this experiment, we have 11 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 599320182
# In this experiment, we have 14 cells, but after filtering, we have 0 cells
# In this experiment, we have 14 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 643062797
# In this experiment, we have 25 cells, but after filtering, we have 9 cells
# In this experiment, we have 25 cells, but after filtering and removing negative mean dffs, we have 9 cells
# Processing experiment 592348507
# In this experiment, we have 15 cells, but after filtering, we have 2 cells
# In this experiment, we have 15 cells, but after filtering and removing negative mean dffs, we have 2 cells
# Processing experiment 603425659
# In this experiment, we have 27 cells, but after filtering, we have 5 cells
# In this experiment, we have 27 cells, but after filtering and removing negative mean dffs, we have 5 cells
# Processing experiment 683253712
# In this experiment, we have 6 cells, but after filtering, we have 2 cells
# In this experiment, we have 6 cells, but after filtering and removing negative mean dffs, we have 2 cells
# Processing experiment 598137246
# In this experiment, we have 20 cells, but after filtering, we have 3 cells
# In this experiment, we have 20 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 642278925
# In this experiment, we have 24 cells, but after filtering, we have 3 cells
# In this experiment, we have 24 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 601273921
# In this experiment, we have 16 cells, but after filtering, we have 1 cells
# In this experiment, we have 16 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 605688822
# In this experiment, we have 10 cells, but after filtering, we have 0 cells
# In this experiment, we have 10 cells, but after filtering and removing negative mean dffs, we have 0 cells
# VISpm [275, 300, 325, 350, 375] ['Sst-IRES-Cre'] #Experiments:  12 #Cells: 38 circ var: 0.8090401118215533
# There are 11 experiments for  VISrl [175] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre']
# Processing experiment 581597734
# In this experiment, we have 297 cells, but after filtering, we have 8 cells
# In this experiment, we have 297 cells, but after filtering and removing negative mean dffs, we have 8 cells
# Processing experiment 574823092
# In this experiment, we have 215 cells, but after filtering, we have 3 cells
# In this experiment, we have 215 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 580095647
# In this experiment, we have 294 cells, but after filtering, we have 12 cells
# In this experiment, we have 294 cells, but after filtering and removing negative mean dffs, we have 12 cells
# Processing experiment 571541565
# In this experiment, we have 138 cells, but after filtering, we have 1 cells
# In this experiment, we have 138 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 698260532
# In this experiment, we have 47 cells, but after filtering, we have 4 cells
# In this experiment, we have 47 cells, but after filtering and removing negative mean dffs, we have 4 cells
# Processing experiment 662351164
# In this experiment, we have 121 cells, but after filtering, we have 10 cells
# In this experiment, we have 121 cells, but after filtering and removing negative mean dffs, we have 10 cells
# Processing experiment 591548033
# In this experiment, we have 45 cells, but after filtering, we have 3 cells
# In this experiment, we have 45 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 569645690
# In this experiment, we have 223 cells, but after filtering, we have 21 cells
# In this experiment, we have 223 cells, but after filtering and removing negative mean dffs, we have 21 cells
# Processing experiment 612536911
# In this experiment, we have 65 cells, but after filtering, we have 0 cells
# In this experiment, we have 65 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 592657427
# In this experiment, we have 103 cells, but after filtering, we have 6 cells
# In this experiment, we have 103 cells, but after filtering and removing negative mean dffs, we have 6 cells
# Processing experiment 594320795
# In this experiment, we have 274 cells, but after filtering, we have 15 cells
# In this experiment, we have 274 cells, but after filtering and removing negative mean dffs, we have 15 cells
# VISrl [175] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre'] #Experiments:  10 #Cells: 83 circ var: 0.9524447830950786
# There are 21 experiments for  VISrl [275, 350] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre']
# Processing experiment 571006300
# In this experiment, we have 304 cells, but after filtering, we have 46 cells
# In this experiment, we have 304 cells, but after filtering and removing negative mean dffs, we have 46 cells
# Processing experiment 593270603
# In this experiment, we have 373 cells, but after filtering, we have 55 cells
# In this experiment, we have 373 cells, but after filtering and removing negative mean dffs, we have 55 cells
# Processing experiment 637154333
# In this experiment, we have 56 cells, but after filtering, we have 1 cells
# In this experiment, we have 56 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 640198011
# In this experiment, we have 369 cells, but after filtering, we have 13 cells
# In this experiment, we have 369 cells, but after filtering and removing negative mean dffs, we have 13 cells
# Processing experiment 710502981
# In this experiment, we have 319 cells, but after filtering, we have 8 cells
# In this experiment, we have 319 cells, but after filtering and removing negative mean dffs, we have 8 cells
# Processing experiment 588655112
# In this experiment, we have 232 cells, but after filtering, we have 0 cells
# In this experiment, we have 232 cells, but after filtering and removing negative mean dffs, we have 0 cells
# Processing experiment 706566686
# In this experiment, we have 93 cells, but after filtering, we have 13 cells
# In this experiment, we have 93 cells, but after filtering and removing negative mean dffs, we have 13 cells
# Processing experiment 560866155
# In this experiment, we have 395 cells, but after filtering, we have 10 cells
# In this experiment, we have 395 cells, but after filtering and removing negative mean dffs, we have 10 cells
# Processing experiment 603592541
# In this experiment, we have 225 cells, but after filtering, we have 7 cells
# In this experiment, we have 225 cells, but after filtering and removing negative mean dffs, we have 7 cells
# Processing experiment 553568031
# In this experiment, we have 326 cells, but after filtering, we have 30 cells
# In this experiment, we have 326 cells, but after filtering and removing negative mean dffs, we have 30 cells
# Processing experiment 658533763
# In this experiment, we have 248 cells, but after filtering, we have 13 cells
# In this experiment, we have 248 cells, but after filtering and removing negative mean dffs, we have 13 cells
# Processing experiment 577665023
# In this experiment, we have 387 cells, but after filtering, we have 9 cells
# In this experiment, we have 387 cells, but after filtering and removing negative mean dffs, we have 9 cells
# Processing experiment 571642389
# In this experiment, we have 340 cells, but after filtering, we have 1 cells
# In this experiment, we have 340 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 644386884
# In this experiment, we have 423 cells, but after filtering, we have 3 cells
# In this experiment, we have 423 cells, but after filtering and removing negative mean dffs, we have 3 cells
# Processing experiment 660064796
# In this experiment, we have 146 cells, but after filtering, we have 4 cells
# In this experiment, we have 146 cells, but after filtering and removing negative mean dffs, we have 4 cells
# Processing experiment 594090967
# In this experiment, we have 418 cells, but after filtering, we have 6 cells
# In this experiment, we have 418 cells, but after filtering and removing negative mean dffs, we have 6 cells
# Processing experiment 570236381
# In this experiment, we have 114 cells, but after filtering, we have 8 cells
# In this experiment, we have 114 cells, but after filtering and removing negative mean dffs, we have 8 cells
# Processing experiment 580013262
# In this experiment, we have 338 cells, but after filtering, we have 7 cells
# In this experiment, we have 338 cells, but after filtering and removing negative mean dffs, we have 7 cells
# Processing experiment 660510593
# In this experiment, we have 155 cells, but after filtering, we have 17 cells
# In this experiment, we have 155 cells, but after filtering and removing negative mean dffs, we have 17 cells
# Processing experiment 570008444
# In this experiment, we have 359 cells, but after filtering, we have 28 cells
# In this experiment, we have 359 cells, but after filtering and removing negative mean dffs, we have 28 cells
# Processing experiment 593552712
# In this experiment, we have 170 cells, but after filtering, we have 5 cells
# In this experiment, we have 170 cells, but after filtering and removing negative mean dffs, we have 5 cells
# VISrl [275, 350] ['Cux2-CreERT2', 'Emx1-IRES-Cre', 'Rorb-IRES2-Cre', 'Nr5a1-Cre'] #Experiments:  20 #Cells: 284 circ var: 0.9519207834149096
# There are 2 experiments for  VISrl [375] ['Rbp4-Cre_KL100 ', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre']
# Processing experiment 582838758
# In this experiment, we have 415 cells, but after filtering, we have 1 cells
# In this experiment, we have 415 cells, but after filtering and removing negative mean dffs, we have 1 cells
# Processing experiment 604328043
# In this experiment, we have 72 cells, but after filtering, we have 9 cells
# In this experiment, we have 72 cells, but after filtering and removing negative mean dffs, we have 9 cells
# VISrl [375] ['Rbp4-Cre_KL100 ', 'Emx1-IRES-Cre', 'Slc17a7-IRES2-Cre'] #Experiments:  2 #Cells: 10 circ var: 0.6540824103150059
# There are 1 experiments for  VISrl [375] ['Sst-IRES-Cre']
# Processing experiment 589755795
# In this experiment, we have 9 cells, but after filtering, we have 2 cells
# In this experiment, we have 9 cells, but after filtering and removing negative mean dffs, we have 2 cells
# VISrl [375] ['Sst-IRES-Cre'] #Experiments:  1 #Cells: 2 circ var: 0.9697628247108596

# %%
test = get_null_cv_samples(agg_theta, agg_r)
test
# Out:
# array([0.625226  , 0.625226  , 0.93971522, 0.57686606, 0.58110009,
#        0.63687399, 0.55358384, 0.65502937])
